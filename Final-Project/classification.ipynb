# %% [markdown]
# # Blood Cell Image Multilabel Classification
#
# In this project, I utilize deep learning models to attempt to classify complex blood cell images into discretized labels (non-binary).
#
# ---

# %% [markdown]
# ## IMPORT STATEMENTS

# %%
# Miscellaneous Notebook, System, and Data Processing Tools
import itertools, cv2, os, csv

# Hierarchical Data Structure Tools
import xml.etree.ElementTree as ETree

# Computational Data Analysis/Visualization Tools
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy

# Keras/Tensorflow Tools
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D, Lambda, MaxPool2D, BatchNormalization
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import RMSprop

# Scikit-Learn Tools
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score

# %% [markdown]
# ### Custom Function to Render Blood Cell Image

# %%
def render_cell_image(img_path):
    img = cv2.imread(img_path)
    plt.imshow(img)
    return

# %% [markdown]
# ### Can Successfully Use `CV2` Library to Render Blood Cell Data!

# %%
plt.figure(figsize=(16,16))

img_path_eosinophil = "./data/dataset2-master/images/TRAIN/EOSINOPHIL/_0_207.jpeg"
plt.subplot(221)
plt.title("EOSINOPHIL")
plt.axis("off") 
render_cell_image(img_path_eosinophil)

img_path_lymphocyte = "./data/dataset2-master/images/TRAIN/LYMPHOCYTE/_0_204.jpeg"
plt.subplot(222)
plt.title("LYMPHOCYTE")
plt.axis("off") 
render_cell_image(img_path_lymphocyte)

img_path_monocyte = "./data/dataset2-master/images/TRAIN/MONOCYTE/_0_180.jpeg"
plt.subplot(223)
plt.title("MONOCYTE")
plt.axis("off") 
render_cell_image(img_path_monocyte)

img_path_neutrophil = "./data/dataset2-master/images/TRAIN/NEUTROPHIL/_0_292.jpeg"
plt.subplot(224)
plt.title("NEUTROPHIL")
plt.axis("OFF") 
render_cell_image(img_path_neutrophil)
